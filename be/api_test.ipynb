# %%
import requests


url = "http://127.0.0.1:5000/users"  # change based on your route

payload = {
    "email": "test@example2.com",
    "password": "mypassword",
    "first_name": "HJonsdhf",
    "last_name": "Sebastian"
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.text)
# Out:
# 201
# {
#   "data": {
#     "email": "test@example2.com"
#   },
#   "message": "User created successfully with ID 2"
# }

# %%
url = "http://127.0.0.1:5000/categories" 
resp = requests.get(url)
print(resp.text)
# Out:
# [
#   {
#     "created_at": "2023-01-16T09:00:00",
#     "id": 201,
#     "name": "Groceries",
#     "type": "expense",
#     "updated_at": "2023-01-16T09:00:00",
#     "user_id": 101
#   },
#   {
#     "created_at": "2023-01-16T09:05:00",
#     "id": 202,
#     "name": "Rent",
#     "type": "expense",
#     "updated_at": "2023-01-16T09:05:00",
#     "user_id": 101
#   },
#   {
#     "created_at": "2023-01-16T09:10:00",
#     "id": 203,
#     "name": "Salary",
#     "type": "income",
#     "updated_at": "2023-01-16T09:10:00",
#     "user_id": 101
#   },
#   {
#     "created_at": "2023-01-16T09:15:00",
#     "id": 204,
#     "name": "Utilities",
#     "type": "expense",
#     "updated_at": "2023-01-16T09:15:00",
#     "user_id": 101
#   },
#   {
#     "created_at": "2023-01-16T09:20:00",
#     "id": 205,
#     "name": "Freelance Project",
#     "type": "income",
#     "updated_at": "2023-01-16T09:20:00",
#     "user_id": 101
#   },
#   {
#     "created_at": "2023-01-16T09:25:00",
# ...
